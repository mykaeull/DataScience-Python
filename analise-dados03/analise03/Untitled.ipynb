# %%
import pandas as pd

# %%
dados = pd.read_csv('cursos-prouni.csv-cursos-prouni.csv.csv', sep=',')

# %%
dados.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
dadosCursosCE = dados.loc[dados.uf_busca == 'CE']
dadosCursosCE
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 1      Bacharelado            Noturno      9836.40                   1.0
# 3      Bacharelado            Noturno      9689.34                   3.0
# 40     Bacharelado           Integral      7783.50                  13.0
# 265    Bacharelado           Matutino      3041.90                   NaN
# 366    Bacharelado           Matutino      2548.12                   3.0
# ...            ...                ...          ...                   ...
# 40643  Bacharelado  Curso a Distância       199.00                   4.0
# 40697  Bacharelado  Curso a Distância       189.00                   NaN
# 41009  Bacharelado  Curso a Distância       177.23                  10.0
# 41071  Tecnológico            Noturno       169.00                   1.0
# 41072  Tecnológico  Curso a Distância       169.00                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
dadosCursosCECC = dadosCursosCE.loc[dadosCursosCE.curso_busca == 'Medicina']
dadosCursosCECC
# Out:
#            grau     turno  mensalidade  bolsa_integral_cotas  \
# 40  Bacharelado  Integral       7783.5                  13.0
#
#     bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 40                   6.0                  NaN                  NaN
#
#       curso_id curso_busca cidade_busca uf_busca     cidade_filtro  \
# 40  3349900844    Medicina    Fortaleza       CE  MjMwMzAxNjA0NDAw
#
#                                     universidade_nome  \
# 40  Centro Universitário Christus - Unichristus - ...
#
#                        campus_nome  campus_external_id      nome  \
# 40  SEDE PARQUE ECOLOGICO - Papicu                3349  Medicina
#
#     nota_integral_ampla  nota_integral_cotas  nota_parcial_ampla  \
# 40                767.9                745.0                 NaN
#
#     nota_parcial_cotas
# 40                 NaN

# %%
dados.uf_busca.value_counts()
# Out:
# SP    11533
# MG     4175
# PR     3918
# RS     3060
# BA     2505
# SC     2195
# RJ     1442
# GO     1278
# PA     1201
# PE     1148
# MT     1063
# DF     1063
# ES      825
# CE      816
# MS      785
# MA      679
# PB      596
# RO      463
# AM      429
# PI      405
# TO      343
# RN      342
# AL      327
# SE      323
# AP      219
# AC      203
# RR      111
# Name: uf_busca, dtype: int64

# %%
dados.uf_busca.value_counts().plot.bar()

# %%
dados[dados.mensalidade == dados.mensalidade.max()]
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
#
#        curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0  706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
#
#                    universidade_nome                         campus_nome  \
# 0  Universidade Anhanguera - UNIDERP  CAMPO GRANDE - SEDE - Miguel Couto
#
#    campus_external_id      nome  nota_integral_ampla  nota_integral_cotas  \
# 0              706710  Medicina               740.22               726.46
#
#    nota_parcial_ampla  nota_parcial_cotas
# 0                 NaN                 NaN

# %%
dados[dados.mensalidade == dados.mensalidade.min()]
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 41444  Tecnológico         Vespertino        139.0                   1.0
# 41445  Bacharelado  Curso a Distância        139.0                   1.0
# 41446  Tecnológico  Curso a Distância        139.0                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 41444                   NaN                  NaN                  NaN
# 41445                   NaN                  NaN                  NaN
# 41446                   1.0                  NaN                  NaN
#
#               curso_id                 curso_busca cidade_busca uf_busca  \
# 41444    1056445674232  Gestão de Recursos Humanos     Brasilia       DF
# 41445      96781210935              Serviço Social      Vitoria       ES
# 41446  200467412868575            Gestão Ambiental     Santarem       PA
#
#           cidade_filtro                                  universidade_nome  \
# ...

# %%
dados.groupby('uf_busca')['mensalidade'].max()
# Out:
# uf_busca
# AC    9674.34
# AL    7290.00
# AM    2127.05
# AP    3607.62
# BA    9048.00
# CE    9836.40
# DF    6757.92
# ES    6022.28
# GO    6484.47
# MA    8281.38
# MG    9350.00
# MS    9999.99
# MT    9208.00
# PA    8508.54
# PB    8350.00
# PE    7250.00
# PI    8402.00
# PR    8466.72
# RJ    9023.07
# RN    6505.09
# RO    6909.97
# RR    1463.05
# RS    8329.95
# SC    6922.15
# SE    6490.00
# SP    9715.61
# TO    7800.00
# Name: mensalidade, dtype: float64

# %%
dados.loc[dados.groupby('uf_busca')['mensalidade'].idxmax()]
# Out:
#               grau     turno  mensalidade  bolsa_integral_cotas  \
# 4      Bacharelado  Integral      9674.34                   4.0
# 67     Bacharelado  Integral      7290.00                   5.0
# 627    Bacharelado  Matutino      2127.05                   4.0
# 202    Bacharelado   Noturno      3607.62                   0.0
# 9      Bacharelado  Integral      9048.00                  13.0
# 1      Bacharelado   Noturno      9836.40                   1.0
# 92     Bacharelado  Integral      6757.92                   8.0
# 118    Bacharelado  Integral      6022.28                   NaN
# 102    Bacharelado  Integral      6484.47                   3.0
# 20     Bacharelado  Integral      8281.38                   3.0
# 7      Bacharelado  Integral      9350.00                   4.0
# 0      Bacharelado  Integral      9999.99                  15.0
# 8      Bacharelado  Integral      9208.00                   7.0
# 13     Bacharelado  Integral      8508.54                   2.0
# ...

# %%
dados[(dados.mensalidade > 500) & (dados.mensalidade < 1000)]
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 7007   Bacharelado            Noturno       999.95                   NaN
# 7008   Bacharelado            Noturno       999.95                   NaN
# 7009   Bacharelado            Noturno       999.95                   0.0
# 7010   Bacharelado            Noturno       999.95                   NaN
# 7011   Bacharelado            Noturno       999.95                   NaN
# ...            ...                ...          ...                   ...
# 17681  Tecnológico            Noturno       500.73                   2.0
# 17682  Tecnológico            Noturno       500.64                   1.0
# 17683  Tecnológico            Noturno       500.61                   NaN
# 17684  Bacharelado  Curso a Distância       500.54                   0.0
# 17685  Bacharelado  Curso a Distância       500.10                   1.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...
